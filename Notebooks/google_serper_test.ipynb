# %%
from langchain.agents import AgentType, initialize_agent, load_tools
from langchain_openai import OpenAI

# %%
# !export OPENAI_API_KEY='mykey'
llm = OpenAI(temperature=0, openai_api_key='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')

# %%
tools = load_tools(["google-serper"], llm=llm)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 tools = load_tools(["google-serper"], llm=llm)
#
# File ~/opt/miniconda3/envs/insite/lib/python3.9/site-packages/langchain/agents/load_tools.py:452, in load_tools(tool_names, llm, callbacks, **kwargs)
#     450     _get_tool_func, extra_keys = _EXTRA_OPTIONAL_TOOLS[name]
#     451     sub_kwargs = {k: kwargs[k] for k in extra_keys if k in kwargs}
# --> 452     tool = _get_tool_func(**sub_kwargs)
#     453     tools.append(tool)
#     454 else:
#
# File ~/opt/miniconda3/envs/insite/lib/python3.9/site-packages/langchain/agents/load_tools.py:214, in _get_google_serper(**kwargs)
#     213 def _get_google_serper(**kwargs: Any) -> BaseTool:
# --> 214     return GoogleSerperRun(api_wrapper=GoogleSerperAPIWrapper(**kwargs))
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.countdown.co.nz/shop/productdetails?stockcode=257153&name=lindt-gold-easter-bunny-milk-hearts-wrap'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 url = 'https://www.countdown.co.nz/shop/productdetails?stockcode=257153&name=lindt-gold-easter-bunny-milk-hearts-wrap'
# ----> 2 response = requests.get(url)
#       3 soup = BeautifulSoup(response.text, 'html.parser')
#
# File ~/opt/miniconda3/envs/insite/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/opt/miniconda3/envs/insite/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
# ...

# %%
# Example: Find all product prices
# Note: This is a hypothetical example. You need to inspect the webpage to find the correct class or id.
for product in soup.find_all('div', class_='product-price'):
    price = product.text.strip()
    print(price)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...
